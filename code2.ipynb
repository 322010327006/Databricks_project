# %%
print("hello world")

# %%
# %sql
select * from workspace.default.customers_100

# %%
# %sql
select city, count(*) from workspace.default.customers_100 group by city

# %%
# %sql
select * from customers_100
    
where `First Name` like '%a%'
